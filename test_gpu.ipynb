# %% [markdown]
# # Ejemplos de TensorFlow GPU en Windows
#
# Este notebook acompaña al [README.md](README.md) con ejemplos de código para verificar la GPU y probar rendimiento.

# %%
import tensorflow as tf
import time

print("=" * 50)
print("TensorFlow:", tf.__version__)
print("=" * 50)

gpus = tf.config.list_physical_devices('GPU')
print("GPUs detectadas:", gpus)

if gpus:
    print("✅ TensorFlow detectó la GPU")
    for gpu in gpus:
        print("GPU:", gpu)

    try:
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except Exception:
        pass
else:
    print("❌ TensorFlow NO detectó la GPU")
# Out:
# ...
# TensorFlow: 2.10.0
# ...
# GPUs detectadas: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ TensorFlow detectó la GPU
# GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# ## Prueba de rendimiento
#
# La siguiente celda fuerza una multiplicación de matrices para comprobar que TensorFlow ejecuta la operación en la GPU cuando está disponible.

# %%
import tensorflow as tf
import time

gpus = tf.config.list_physical_devices('GPU')

with tf.device('/GPU:0' if gpus else '/CPU:0'):
    inicio = time.time()
    a = tf.random.normal([5000, 5000])
    b = tf.random.normal([5000, 5000])
    c = tf.matmul(a, b)
    _ = c.numpy()
    fin = time.time()

print("Tiempo:", fin - inicio)
print("Resultado:", c.shape)
# Out:
# Tiempo: 0.2279210090637207
# Resultado: (5000, 5000)
